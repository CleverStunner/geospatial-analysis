# %%
import geopandas as gpd

# %%
#reading geopandas
in_shp = r"C:\Users\B.A.B\OneDrive\Documents\Codes\Python\Geospatial analysis\Ghana_shp"

# %%
gdf = gpd.read_file(in_shp)

# %%
gdf.head()
# Out:
#     GID_1 GID_0 COUNTRY     NAME_1 VARNAME_1 NL_NAME_1  TYPE_1 ENGTYPE_1 CC_1  \
# 0  GHA1_2   GHA   Ghana      Ahafo        NA        NA  Region    Region   NA
# 1  GHA2_2   GHA   Ghana    Ashanti        NA        NA  Region    Region   NA
# 2  GHA3_2   GHA   Ghana       Bono        NA        NA  Region    Region   NA
# 3  GHA4_2   GHA   Ghana  Bono East        NA        NA  Region    Region   NA
# 4  GHA5_2   GHA   Ghana    Central        NA        NA  Region    Region   NA
#
#   HASC_1  ISO_1                                           geometry
# 0     NA  GH-AF  POLYGON ((-2.41599 6.6588, -2.41612 6.65887, -...
# 1     NA  GH-AH  POLYGON ((-0.75537 6.91273, -0.75536 6.9127, -...
# 2     NA  GH-BO  POLYGON ((-2.86623 6.8524, -2.86639 6.85248, -...
# 3     NA  GH-BE  POLYGON ((-1.43358 7.57346, -1.4352 7.56992, -...
# 4     NA  GH-CP  POLYGON ((-0.75619 5.71017, -0.75569 5.71023, ...

# %%
#number of records in the geodatabase
len(gdf)
# Out:
# 16

# %%
#coordinate system of shapefile
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#geometry type
gdf.geom_type
# Out:
# 0     Polygon
# 1     Polygon
# 2     Polygon
# 3     Polygon
# 4     Polygon
# 5     Polygon
# 6     Polygon
# 7     Polygon
# 8     Polygon
# 9     Polygon
# 10    Polygon
# 11    Polygon
# 12    Polygon
# 13    Polygon
# 14    Polygon
# 15    Polygon
# dtype: object

# %%
#visualizing a vector dataset
gdf.plot("NAME_1", legend=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, figsize=(6.5, 10))

gdf.plot(ax=ax, column="NAME_1", legend=True, 
         legend_kwds={
             "loc": "upper left",
             "bbox_to_anchor": (1.05, 1),
             "title": "Legend"
         })

plt.tight_layout()
plt.show()

# %%
#writing vector data
gdf.to_file(r"C:\Users\B.A.B\OneDrive\Documents\Codes\Python\Geospatial analysis\output\output.shp")
